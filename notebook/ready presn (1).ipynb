# %%
import pandas as pd

df = pd.read_csv('CSV.us.csv')
df
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_10620\2590645095.py:3: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('CSV.us.csv')
#        Year  Month           State           Primary Mode  \
# 0      2016      1      New Jersey                   Food
# 1      2018      9   Massachusetts       Person-to-person
# 2      2023      1       Minnesota                   Food
# 3      2023      1   Massachusetts  Indeterminate/unknown
# 4      2023      1  North Carolina       Person-to-person
# ...     ...    ...             ...                    ...
# 66708  1971     11          Alaska                  Water
# 66709  1971     11        New York                  Water
# 66710  1971     11        Oklahoma                  Water
# 66711  1971     11           Texas                  Water
# 66712  1971     12      California                  Water
#
# ...

# %%
df['State'].value_counts().head(5).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
import pandas as pd
df = pd.read_csv(import pandas as pd
primarymode = df.groupby('Primary Mode')['Illnesses'].sum().reset_index()
primarymode = primarymode.sort_values(by='Illnesses', ascending = False)
primarymode
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_10620\2026704330.py:2: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('CSV.us.csv')
#                                         Primary Mode  Illnesses
# 4                                   Person-to-person     980727
# 5                                              Water     654593
# 2                                               Food     467790
# 3                              Indeterminate/unknown      94112
# 0                                     Animal contact      17376
# 1  Environmental contamination other than food/water       3720

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.barplot(primarymode, y= "Primary Mode",x = 'Illnesses')
plt.xticks(rotation=90);

# %%
import pandas as pd
df = pd.read_csv('CSV.us.csv')
deathsreported = df.groupby('State')['Info On Deaths'].sum().reset_index()
deathsreported = deathsreported.sort_values(by = 'Info On Deaths', ascending = False)
deathsreported
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_10620\3747418325.py:2: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('CSV.us.csv')
#                                State  Info On Deaths
# 56                         Wisconsin         83768.0
# 41                      Pennsylvania         76729.0
# 53                          Virginia         74087.0
# 14                          Illinois         66127.0
# 38                              Ohio         58966.0
# 40                            Oregon         51550.0
# 22                     Massachusetts         45320.0
# 24                         Minnesota         44907.0
# 23                          Michigan         42914.0
# 35                    North Carolina         39309.0
# 28                        Multistate         38914.0
# 4                         California         37090.0
# 5                           Colorado         36816.0
# ...

# %%
sns.barplot(deathsreported.head(20), y='State', x='Info On Deaths');
